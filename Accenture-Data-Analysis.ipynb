# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
# Print the current working directory
print(os.getcwd())
# Out:
# C:\Users\shiva\Documents\Python-revice\Projects-DataAnalysis

# %% [markdown]
# #### Read CSV

# %%
pd_Content=pd.read_csv("./Accerture/Content.csv")
pd_reaction=pd.read_csv("./Accerture/Reactions.csv")
pd_reactionTypes=pd.read_csv("./Accerture/ReactionTypes.csv")

# %% [markdown]
# ### Shape

# %%
pd_Content.shape
# Out:
# (801, 5)

# %%
pd_reaction.shape
# Out:
# (22534, 4)

# %%
pd_reactionTypes.shape
# Out:
# (16, 3)

# %%
pd_reaction.head()
# Out:
#                              Content ID                               User ID  \
# 1  97522e57-d9ab-4bd6-97bf-c24d952602d2  5d454588-283d-459d-915d-c48a2cb4c27f
# 2  97522e57-d9ab-4bd6-97bf-c24d952602d2  92b87fa5-f271-43e0-af66-84fac21052e6
# 3  97522e57-d9ab-4bd6-97bf-c24d952602d2  163daa38-8b77-48c9-9af6-37a6c1447ac2
# 4  97522e57-d9ab-4bd6-97bf-c24d952602d2  34e8add9-0206-47fd-a501-037b994650a2
# 5  97522e57-d9ab-4bd6-97bf-c24d952602d2  9b6d35f9-5e15-4cd0-a8d7-b1f3340e02c4
#
#          Type            Datetime
# 1     disgust 2020-11-07 09:43:50
# 2     dislike 2021-06-17 12:22:51
# 3      scared 2021-04-18 05:13:58
# 4     disgust 2021-01-06 19:13:01
# 5  interested 2020-08-23 12:25:58

# %%
pd_reactionTypes.head()
# Out:
#          Type Sentiment  Score
# 0       heart  positive     60
# 1        want  positive     70
# 2     disgust  negative      0
# 3        hate  negative      5
# 4  interested  positive     30

# %% [markdown]
# ### Finding Missing Values

# %%
#Null values in the content 
pd_Content.isnull().sum()
# Out:
# Content ID    0
# User ID       0
# Type          0
# Category      0
# URL           0
# dtype: int64

# %%
pd_reaction.isna().sum()
# Out:
# Content ID    0
# User ID       0
# Type          0
# Datetime      0
# dtype: int64

# %%
pd_reactionTypes.isna().sum()
# Out:
# Type         0
# Sentiment    0
# Score        0
# dtype: int64

# %%
#Plot the missing values

# %%
missing = pd.DataFrame((pd_Content.isnull().sum())*100/pd_Content.shape[0]).reset_index()
missing.columns = ['column', 'percentage']  # Rename columns for clarity

plt.figure(figsize=(16,5))
ax = sns.pointplot(x='column', y='percentage',data=missing)
plt.xlabel("Feature",labelpad=14)
plt.xticks(rotation =90,fontsize =10)
plt.title("Percentage of Missing values")
plt.ylabel("PERCENTAGE",labelpad=14)
plt.show()

# %%
missing = pd.DataFrame((pd_reaction.isnull().sum())*100/pd_reaction.shape[0]).reset_index()
missing.columns = ['column', 'percentage']  # Rename columns for clarity

plt.figure(figsize=(16,5))
ax = sns.pointplot(x='column', y='percentage',data=missing)
plt.xlabel("Feature",labelpad=14)
plt.xticks(rotation =90,fontsize =10)
plt.title("Percentage of Missing values")
plt.ylabel("PERCENTAGE",labelpad=14)
plt.show()

# %%
missing = pd.DataFrame((pd_reactionTypes.isnull().sum())*100/pd_reactionTypes.shape[0]).reset_index()
missing.columns = ['column', 'percentage']  # Rename columns for clarity

plt.figure(figsize=(16,5))
ax = sns.pointplot(x='column', y='percentage',data=missing)
plt.xlabel("Feature",labelpad=14)
plt.xticks(rotation =90,fontsize =10)
plt.title("Percentage of Missing values")
plt.ylabel("PERCENTAGE",labelpad=14)
plt.show()

# %% [markdown]
# ### Remove the Rows that are missing

# %%
#Removing missing values 
pd_Content.dropna(how = 'any', inplace = True)

# %%
pd_reaction.dropna(how = 'any', inplace = True)

# %% [markdown]
# #### Change the data types if needed

# %%
#get the dtpes of each data set
# pd_Content = pd.to_numeric(telco_data.TotalCharges, errors='coerce')#if there is invalid parsing the it is converted to Nan
# pd_Content[columns_to_convert]=pd_Content[columns_to_convert].apply(pd.,errors="coerce")

# %%
pd_Content.head()
# Out:
#                              Content ID                               User ID  \
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2  8d3cd87d-8a31-4935-9a4f-b319bfe05f31
# 1  9f737e0a-3cdd-4d29-9d24-753f4e3be810  beb1f34e-7870-46d6-9fc7-2e12eb83ce43
# 2  230c4e4d-70c3-461d-b42c-ec09396efb3f  a5c65404-5894-4b87-82f2-d787cbee86b4
# 3  356fff80-da4d-4785-9f43-bc1261031dc6  9fb4ce88-fac1-406c-8544-1a899cee7aaf
# 4  01ab84dd-6364-4236-abbb-3f237db77180  e206e31b-5f85-4964-b6ea-d7ee5324def1
#
#     Type        Category                                                URL
# 0  photo        Studying  https://socialbuzz.cdn.com/content/storage/975...
# 1  photo  healthy eating  https://socialbuzz.cdn.com/content/storage/9f7...
# 2  photo  healthy eating  https://socialbuzz.cdn.com/content/storage/230...
# 3  photo      technology  https://socialbuzz.cdn.com/content/storage/356...
# 4  video            food  https://socialbuzz.cdn.com/content/storage/01a...

# %%
pd_reaction.dtypes
columns_to_convert=["Datetime"]
pd_reaction[columns_to_convert]=pd_reaction[columns_to_convert].apply(pd.to_datetime,errors='coerce')

# %%
pd_reaction.head()
# Out:
#                              Content ID                               User ID  \
# 1  97522e57-d9ab-4bd6-97bf-c24d952602d2  5d454588-283d-459d-915d-c48a2cb4c27f
# 2  97522e57-d9ab-4bd6-97bf-c24d952602d2  92b87fa5-f271-43e0-af66-84fac21052e6
# 3  97522e57-d9ab-4bd6-97bf-c24d952602d2  163daa38-8b77-48c9-9af6-37a6c1447ac2
# 4  97522e57-d9ab-4bd6-97bf-c24d952602d2  34e8add9-0206-47fd-a501-037b994650a2
# 5  97522e57-d9ab-4bd6-97bf-c24d952602d2  9b6d35f9-5e15-4cd0-a8d7-b1f3340e02c4
#
#          Type            Datetime
# 1     disgust 2020-11-07 09:43:50
# 2     dislike 2021-06-17 12:22:51
# 3      scared 2021-04-18 05:13:58
# 4     disgust 2021-01-06 19:13:01
# 5  interested 2020-08-23 12:25:58

# %%
pd_reaction.dtypes
# Out:
# Content ID            object
# User ID               object
# Type                  object
# Datetime      datetime64[ns]
# dtype: object

# %%
pd_reactionTypes.dtypes
# Out:
# Type         object
# Sentiment    object
# Score         int64
# dtype: object

# %% [markdown]
# #### Drop the columns that are unnessesary

# %%
pd_Content.drop(columns= ['Unnamed: 0'], axis=1, inplace=True)
pd_Content.head()
# Out:
#                              Content ID                               User ID  \
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2  8d3cd87d-8a31-4935-9a4f-b319bfe05f31
# 1  9f737e0a-3cdd-4d29-9d24-753f4e3be810  beb1f34e-7870-46d6-9fc7-2e12eb83ce43
# 2  230c4e4d-70c3-461d-b42c-ec09396efb3f  a5c65404-5894-4b87-82f2-d787cbee86b4
# 3  356fff80-da4d-4785-9f43-bc1261031dc6  9fb4ce88-fac1-406c-8544-1a899cee7aaf
# 4  01ab84dd-6364-4236-abbb-3f237db77180  e206e31b-5f85-4964-b6ea-d7ee5324def1
#
#     Type        Category                                                URL
# 0  photo        Studying  https://socialbuzz.cdn.com/content/storage/975...
# 1  photo  healthy eating  https://socialbuzz.cdn.com/content/storage/9f7...
# 2  photo  healthy eating  https://socialbuzz.cdn.com/content/storage/230...
# 3  photo      technology  https://socialbuzz.cdn.com/content/storage/356...
# 4  video            food  https://socialbuzz.cdn.com/content/storage/01a...

# %%
pd_reaction.drop(columns= ['Unnamed: 0'], axis=1, inplace=True)
pd_reaction.head()
# Out:
#                              Content ID                               User ID  \
# 1  97522e57-d9ab-4bd6-97bf-c24d952602d2  5d454588-283d-459d-915d-c48a2cb4c27f
# 2  97522e57-d9ab-4bd6-97bf-c24d952602d2  92b87fa5-f271-43e0-af66-84fac21052e6
# 3  97522e57-d9ab-4bd6-97bf-c24d952602d2  163daa38-8b77-48c9-9af6-37a6c1447ac2
# 4  97522e57-d9ab-4bd6-97bf-c24d952602d2  34e8add9-0206-47fd-a501-037b994650a2
# 5  97522e57-d9ab-4bd6-97bf-c24d952602d2  9b6d35f9-5e15-4cd0-a8d7-b1f3340e02c4
#
#          Type             Datetime
# 1     disgust  2020-11-07 09:43:50
# 2     dislike  2021-06-17 12:22:51
# 3      scared  2021-04-18 05:13:58
# 4     disgust  2021-01-06 19:13:01
# 5  interested  2020-08-23 12:25:58

# %%
pd_reactionTypes.drop(columns= ['Unnamed: 0'], axis=1, inplace=True)
pd_reactionTypes.head()
# Out:
#          Type Sentiment  Score
# 0       heart  positive     60
# 1        want  positive     70
# 2     disgust  negative      0
# 3        hate  negative      5
# 4  interested  positive     30

# %% [markdown]
# #### Look for Top Three Performing Columns

# %%
pd_Content.head(10)
# Out:
#                               Content ID  \
# 0   97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1   9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2   230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3   356fff80-da4d-4785-9f43-bc1261031dc6
# 4   01ab84dd-6364-4236-abbb-3f237db77180
# 6   3f8590c7-6ab2-4973-805a-90cdec355f05
# 7   e5490118-90d5-4572-ab1c-1fbc87b8d9ca
# 8   0bedca96-fb76-4287-a83c-17330ed39cce
# 9   b18cb63f-4c8e-44ee-a47f-541e95191d11
# 11  46fb701d-6c26-458e-ada3-2ebe5dbba01f
#
#                                  User ID   Type         Category  \
# 0   8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo         Studying
# 1   beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo   healthy eating
# 2   a5c65404-5894-4b87-82f2-d787cbee86b4  photo   healthy eating
# 3   9fb4ce88-fac1-406c-8544-1a899cee7aaf  photo       technology
# 4   e206e31b-5f85-4964-b6ea-d7ee5324def1  video             food
# 6   ae600af5-c1f0-4b1f-adb0-1b4c246373e4  video             dogs
# 7   583f2bde-886d-4cf3-a5c4-7cb60cd25df3  video       technology
# 8   2bd9c167-e06c-47c1-a978-3403d6724606  photo           soccer
# 9   13f0db8a-152a-496f-a6e8-1ed6a90b8788  photo  public speaking
# 11  4fe1900d-5e78-41a3-88ed-18e6889c6c77  audio  public speaking
#
#                                                   URL
# 0   https://socialbuzz.cdn.com/content/storage/975...
# 1   https://socialbuzz.cdn.com/content/storage/9f7...
# 2   https://socialbuzz.cdn.com/content/storage/230...
# 3   https://socialbuzz.cdn.com/content/storage/356...
# 4   https://socialbuzz.cdn.com/content/storage/01a...
# 6   https://socialbuzz.cdn.com/content/storage/3f8...
# 7   https://socialbuzz.cdn.com/content/storage/e54...
# 8   https://socialbuzz.cdn.com/content/storage/0be...
# 9   https://socialbuzz.cdn.com/content/storage/b18...
# 11  https://socialbuzz.cdn.com/content/storage/46f...

# %%
pd_reaction.head(10)
# Out:
#                               Content ID  \
# 1   97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2   97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3   97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4   97522e57-d9ab-4bd6-97bf-c24d952602d2
# 5   97522e57-d9ab-4bd6-97bf-c24d952602d2
# 6   97522e57-d9ab-4bd6-97bf-c24d952602d2
# 7   97522e57-d9ab-4bd6-97bf-c24d952602d2
# 8   97522e57-d9ab-4bd6-97bf-c24d952602d2
# 9   97522e57-d9ab-4bd6-97bf-c24d952602d2
# 11  97522e57-d9ab-4bd6-97bf-c24d952602d2
#
#                                  User ID         Type            Datetime
# 1   5d454588-283d-459d-915d-c48a2cb4c27f      disgust 2020-11-07 09:43:50
# 2   92b87fa5-f271-43e0-af66-84fac21052e6      dislike 2021-06-17 12:22:51
# 3   163daa38-8b77-48c9-9af6-37a6c1447ac2       scared 2021-04-18 05:13:58
# 4   34e8add9-0206-47fd-a501-037b994650a2      disgust 2021-01-06 19:13:01
# 5   9b6d35f9-5e15-4cd0-a8d7-b1f3340e02c4   interested 2020-08-23 12:25:58
# 6   7918d465-0953-4f20-9e28-539e74c82e2f      peeking 2020-12-07 06:27:54
# 7   fa3e42f0-71d8-455f-b024-e52d5c27a145      cherish 2021-04-11 17:35:49
# 8   b0c22f82-b882-4394-bf27-6dfadf26e5c2         hate 2021-01-27 08:32:09
# 9   1932a904-86ba-4438-bb52-b7e6516a4019      peeking 2021-04-01 22:54:23
# 11  f50ac030-3af8-4e07-aacf-dccff353b8f6  indifferent 2020-11-07 08:36:27

# %%
pd_reactionTypes.head(10)
# Out:
#           Type Sentiment  Score
# 0        heart  positive     60
# 1         want  positive     70
# 2      disgust  negative      0
# 3         hate  negative      5
# 4   interested  positive     30
# 5  indifferent   neutral     20
# 6         love  positive     65
# 7   super love  positive     75
# 8      cherish  positive     70
# 9        adore  positive     72

# %%
#Create the data set Merging the tables Of Reaction and Content

# %%
# Merge the datasets on 'contentid' and 'userid'
merged_df = pd.merge(pd_Content, pd_reaction, on=['Content ID', 'User ID'], how='inner')

# %%
merged_df.head()
# Out:
#                              Content ID                               User ID  \
# 0  36d36f19-7a10-4d7d-a3ab-a3f2cbbfcf4a  69532ce2-1ffe-4187-8042-0230d115b24e
# 1  f1038e6c-5292-4e20-a866-675e1637d6b5  13f0db8a-152a-496f-a6e8-1ed6a90b8788
# 2  ff883828-a610-492d-8635-8a777eaad25f  ded166ee-173b-4a56-bc6d-464c35709670
# 3  a3e93c2d-7fb4-4881-994d-ee20ad564924  317c70d5-fe65-4663-afb1-150108e0e55c
# 4  b4c71928-99f0-4f1e-bdff-3d99c16113ac  bf721d00-4fa1-44b1-834f-4730cd51aefa
#
#   Type_x         Category                                                URL  \
# 0  photo             food  https://socialbuzz.cdn.com/content/storage/36d...
# 1    GIF           soccer  https://socialbuzz.cdn.com/content/storage/f10...
# 2  photo        education  https://socialbuzz.cdn.com/content/storage/ff8...
# 3  video  public speaking  https://socialbuzz.cdn.com/content/storage/a3e...
# 4  video           travel  https://socialbuzz.cdn.com/content/storage/b4c...
#
#     Type_y            Datetime
# 0  worried 2021-02-12 00:36:14
# 1  cherish 2020-09-01 12:38:42
# 2  peeking 2021-02-07 12:32:32
# 3    adore 2020-08-10 10:44:10
# 4   scared 2021-06-08 06:56:52

# %%
# mergedwithreaction=# Merge df2 with reaction_df using different column names for joining
mergedwithreaction = pd.merge(merged_df, pd_reactionTypes, left_on='Type_y', right_on='Type', how='left')

mergedwithreaction.drop(columns='type', inplace=True)

# print(merged_df2)

# %%
mergedwithreaction
# Out:
#                               Content ID  \
# 0   36d36f19-7a10-4d7d-a3ab-a3f2cbbfcf4a
# 1   f1038e6c-5292-4e20-a866-675e1637d6b5
# 2   ff883828-a610-492d-8635-8a777eaad25f
# 3   a3e93c2d-7fb4-4881-994d-ee20ad564924
# 4   b4c71928-99f0-4f1e-bdff-3d99c16113ac
# 5   4b10b6a2-d8ad-4f48-835a-e0ec47e7e72c
# 6   802a8533-3051-4e2c-ad30-7751ece5d514
# 7   9ee8836d-af4b-46ad-8869-4e0b1dedff7d
# 8   b81f446e-be9b-4fff-8faf-7732c6306c75
# 9   b07a2298-7c03-49b3-a0a6-c65333847598
# 10  fc346df4-d165-4ed0-8d43-a6896daf908e
# 11  88cbf75c-79f0-42cb-8733-af670f39d6e0
# 12  4c009116-c94a-4633-83fb-956565358565
# 13  3cec7ac2-f9b6-4e4c-b392-63c59c3621f2
# 14  6fd589e8-53ab-4345-896a-f428a92fcbe6
# 15  6fd589e8-53ab-4345-896a-f428a92fcbe6
# 16  a38cf15e-6a1d-42e8-bee7-0eeb456c700b
# 17  6a39e0b5-b1cd-4edd-bdfb-310e1a3e5910
# 18  f8119ef8-1f00-49e4-b468-86dd64042053
# 19  1cd59d79-a2ca-4a99-92aa-2775117c4589
# 20  87958932-6baf-4339-b01b-6112d9b180ed
# 21  bead7e6d-0e1f-489d-81b2-d006a67b5b33
# 22  72167d71-578d-428f-af6d-5a8a92e677af
# 23  292051b5-b835-4a60-962a-bddf10da82bd
# 24  02664d35-87cf-46a6-a80b-78fbc9ac8b2f
# 25  e0cb0394-c5b2-447a-a9f4-88604a3ec283
# 26  3f6b1a9d-db78-4d9a-a495-9de7bd9bbe5b
# 27  7cace87f-53ff-40c0-99f5-abbc5b8f86d6
# 28  445a06c1-3dea-4129-90eb-2384c0534eb6
# 29  5ac2552c-15a5-41ed-8d67-9c57bce74ebc
# 30  9b480f9e-cef3-46cc-8ea1-c116cded9661
# 31  f0c6ae88-c87e-4812-9713-ae45018a1f73
# 32  c4cc899d-4c35-47fd-9710-8e2dea9782c9
# 33  74989207-b147-4a13-89b8-f0d868dfdf4a
# 34  c54b49c4-b1f2-4641-8595-1cbd19937845
#
#                                  User ID Type_x         Category  \
# 0   69532ce2-1ffe-4187-8042-0230d115b24e  photo             food
# 1   13f0db8a-152a-496f-a6e8-1ed6a90b8788    GIF           soccer
# 2   ded166ee-173b-4a56-bc6d-464c35709670  photo        education
# 3   317c70d5-fe65-4663-afb1-150108e0e55c  video  public speaking
# 4   bf721d00-4fa1-44b1-834f-4730cd51aefa  video           travel
# 5   bf721d00-4fa1-44b1-834f-4730cd51aefa  photo        education
# 6   600118fa-e6f4-4d74-aeb6-936abbbf38a1  audio             food
# 7   90e2caab-9daa-4bf0-8104-c25e6c70c59d  audio           tennis
# 8   d1a89d23-7d17-4949-9e1a-637317141f3d  audio          cooking
# 9   ad4bd878-55e7-487c-a4db-470b23bbd832    GIF          culture
# 10  4bcb2c2e-36ed-4d5d-90a1-440993e9f6d2  video  public speaking
# 11  b473e898-b7b0-4a57-959d-484bf4cc4483  audio          animals
# 12  6fd58dea-315a-4ab2-8023-424a6ff455cd  photo           soccer
# 13  5b62e10e-3c19-4d28-a57c-e9bdc3d6758d    GIF   healthy eating
# 14  561b08d6-1084-4115-933d-db3e60edfd8b  video        education
# 15  561b08d6-1084-4115-933d-db3e60edfd8b  video        education
# 16  30be2156-59d1-451e-beea-1a3690200a2b  video           travel
# 17  c64c5004-6ab5-4faa-9fcd-8039fe57799d    GIF           soccer
# 18  375985a6-ae79-43d2-b7c6-b182d83f1eaf  photo          culture
# 19  b870b764-7447-4990-a8d4-024d33e0e67d  audio          science
# 20  5ff89fb3-b364-494f-b62d-07097b2ffa12  audio          culture
# 21  c64c5004-6ab5-4faa-9fcd-8039fe57799d    GIF          science
# 22  4fe1900d-5e78-41a3-88ed-18e6889c6c77  photo          animals
# 23  311d7214-711f-4f66-bc9a-e835fa54ffb6  photo       technology
# 24  69fcad9e-45a9-4189-b7e1-96b26c57c542    GIF          science
# 25  92423e9a-4e8c-49bc-be75-c819912696ce  audio  public speaking
# 26  1a1be722-70b0-47e0-a737-1700cffa1e6d    GIF           tennis
# 27  c5d04879-87bd-4950-9e63-334382ef53af    GIF          cooking
# 28  91bec0ab-a8d4-421e-b333-e511c7c6f9a0    GIF       technology
# 29  33c1cee6-ae56-4f8e-84fc-ee0a4b7bbf4c  video           travel
# 30  c76c3393-88e2-47b0-ac37-dc4f2053f5a5  audio  public speaking
# 31  db0066e1-83cc-43f3-990b-983010aa5370  photo          science
# 32  1ff398e4-6b68-451d-9b00-2d2a565ba22a  photo          science
# 33  d56c9d87-7d56-4a5e-a0e8-bbc4ddc3242c  audio          science
# 34  2ab641a8-6ad4-4d1a-8511-d87ff5346773  photo          science
#
#                                                   URL       Type_y  \
# 0   https://socialbuzz.cdn.com/content/storage/36d...      worried
# 1   https://socialbuzz.cdn.com/content/storage/f10...      cherish
# 2   https://socialbuzz.cdn.com/content/storage/ff8...      peeking
# 3   https://socialbuzz.cdn.com/content/storage/a3e...        adore
# 4   https://socialbuzz.cdn.com/content/storage/b4c...       scared
# 5   https://socialbuzz.cdn.com/content/storage/4b1...      dislike
# 6   https://socialbuzz.cdn.com/content/storage/802...      disgust
# 7   https://socialbuzz.cdn.com/content/storage/9ee...         hate
# 8   https://socialbuzz.cdn.com/content/storage/b81...         want
# 9   https://socialbuzz.cdn.com/content/storage/b07...         love
# 10  https://socialbuzz.cdn.com/content/storage/fc3...         love
# 11  https://socialbuzz.cdn.com/content/storage/88c...   super love
# 12  https://socialbuzz.cdn.com/content/storage/4c0...   interested
# 13  https://socialbuzz.cdn.com/content/storage/3ce...      peeking
# 14  https://socialbuzz.cdn.com/content/storage/6fd...         love
# 15  https://socialbuzz.cdn.com/content/storage/6fd...   interested
# 16  https://socialbuzz.cdn.com/content/storage/a38...         like
# 17  https://socialbuzz.cdn.com/content/storage/6a3...      peeking
# 18  https://socialbuzz.cdn.com/content/storage/f81...         want
# 19  https://socialbuzz.cdn.com/content/storage/1cd...       scared
# 20  https://socialbuzz.cdn.com/content/storage/879...       scared
# 21  https://socialbuzz.cdn.com/content/storage/bea...  indifferent
# 22  https://socialbuzz.cdn.com/content/storage/721...         want
# 23  https://socialbuzz.cdn.com/content/storage/292...      disgust
# 24  https://socialbuzz.cdn.com/content/storage/026...      dislike
# 25  https://socialbuzz.cdn.com/content/storage/e0c...         love
# 26  https://socialbuzz.cdn.com/content/storage/3f6...   interested
# 27  https://socialbuzz.cdn.com/content/storage/7ca...         love
# 28  https://socialbuzz.cdn.com/content/storage/445...         hate
# 29  https://socialbuzz.cdn.com/content/storage/5ac...         like
# 30  https://socialbuzz.cdn.com/content/storage/9b4...   interested
# 31  https://socialbuzz.cdn.com/content/storage/f0c...      worried
# 32  https://socialbuzz.cdn.com/content/storage/c4c...         love
# 33  https://socialbuzz.cdn.com/content/storage/749...        heart
# 34  https://socialbuzz.cdn.com/content/storage/c54...    intrigued
#
#               Datetime         Type Sentiment  Score
# 0  2021-02-12 00:36:14      worried  negative     12
# 1  2020-09-01 12:38:42      cherish  positive     70
# 2  2021-02-07 12:32:32      peeking   neutral     35
# 3  2020-08-10 10:44:10        adore  positive     72
# 4  2021-06-08 06:56:52       scared  negative     15
# 5  2020-07-22 10:41:19      dislike  negative     10
# 6  2021-03-30 17:47:26      disgust  negative      0
# 7  2021-02-18 09:20:59         hate  negative      5
# 8  2020-12-05 13:32:27         want  positive     70
# 9  2020-07-14 18:19:05         love  positive     65
# 10 2020-09-26 14:19:03         love  positive     65
# 11 2020-10-09 06:07:21   super love  positive     75
# 12 2020-12-16 22:54:33   interested  positive     30
# 13 2020-09-29 15:38:29      peeking   neutral     35
# 14 2021-04-17 11:05:23         love  positive     65
# 15 2021-01-31 17:50:55   interested  positive     30
# 16 2020-10-27 12:38:55         like  positive     50
# 17 2020-11-23 08:41:19      peeking   neutral     35
# 18 2021-05-18 05:54:33         want  positive     70
# 19 2020-08-18 00:50:44       scared  negative     15
# 20 2020-11-13 03:25:01       scared  negative     15
# 21 2021-05-09 09:19:08  indifferent   neutral     20
# 22 2021-03-24 05:46:11         want  positive     70
# 23 2021-02-16 09:28:11      disgust  negative      0
# 24 2021-05-08 18:38:17      dislike  negative     10
# 25 2020-10-20 03:55:18         love  positive     65
# 26 2020-10-15 13:41:42   interested  positive     30
# 27 2021-02-06 15:47:55         love  positive     65
# 28 2021-03-08 03:56:30         hate  negative      5
# 29 2021-05-11 14:50:07         like  positive     50
# 30 2021-01-15 13:36:52   interested  positive     30
# 31 2020-09-02 09:24:13      worried  negative     12
# 32 2020-12-22 08:42:27         love  positive     65
# 33 2020-08-01 15:39:57        heart  positive     60
# 34 2020-09-11 07:06:30    intrigued  positive     45

# %%
mergedwithreaction.drop(columns='Type', inplace=True)

# %%
mergedwithreaction["Content ID"].unique().size
# Out:
# 34

# %%
mergedwithreaction["Content ID"].nunique()
# Out:
# 34

# %%
mergedwithreaction["Content ID",""].duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15     True
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# Name: Content ID, dtype: bool

# %%
mergedwithreaction.drop_duplicates(subset=["Content ID","User ID"], keep='first',inplace=True)

# %%
mergedwithreaction.head(10)
# Out:
#                              Content ID                               User ID  \
# 0  36d36f19-7a10-4d7d-a3ab-a3f2cbbfcf4a  69532ce2-1ffe-4187-8042-0230d115b24e
# 1  f1038e6c-5292-4e20-a866-675e1637d6b5  13f0db8a-152a-496f-a6e8-1ed6a90b8788
# 2  ff883828-a610-492d-8635-8a777eaad25f  ded166ee-173b-4a56-bc6d-464c35709670
# 3  a3e93c2d-7fb4-4881-994d-ee20ad564924  317c70d5-fe65-4663-afb1-150108e0e55c
# 4  b4c71928-99f0-4f1e-bdff-3d99c16113ac  bf721d00-4fa1-44b1-834f-4730cd51aefa
# 5  4b10b6a2-d8ad-4f48-835a-e0ec47e7e72c  bf721d00-4fa1-44b1-834f-4730cd51aefa
# 6  802a8533-3051-4e2c-ad30-7751ece5d514  600118fa-e6f4-4d74-aeb6-936abbbf38a1
# 7  9ee8836d-af4b-46ad-8869-4e0b1dedff7d  90e2caab-9daa-4bf0-8104-c25e6c70c59d
# 8  b81f446e-be9b-4fff-8faf-7732c6306c75  d1a89d23-7d17-4949-9e1a-637317141f3d
# 9  b07a2298-7c03-49b3-a0a6-c65333847598  ad4bd878-55e7-487c-a4db-470b23bbd832
#
#   Type_x         Category                                                URL  \
# 0  photo             food  https://socialbuzz.cdn.com/content/storage/36d...
# 1    GIF           soccer  https://socialbuzz.cdn.com/content/storage/f10...
# 2  photo        education  https://socialbuzz.cdn.com/content/storage/ff8...
# 3  video  public speaking  https://socialbuzz.cdn.com/content/storage/a3e...
# 4  video           travel  https://socialbuzz.cdn.com/content/storage/b4c...
# 5  photo        education  https://socialbuzz.cdn.com/content/storage/4b1...
# 6  audio             food  https://socialbuzz.cdn.com/content/storage/802...
# 7  audio           tennis  https://socialbuzz.cdn.com/content/storage/9ee...
# 8  audio          cooking  https://socialbuzz.cdn.com/content/storage/b81...
# 9    GIF          culture  https://socialbuzz.cdn.com/content/storage/b07...
#
#     Type_y            Datetime Sentiment  Score
# 0  worried 2021-02-12 00:36:14  negative     12
# 1  cherish 2020-09-01 12:38:42  positive     70
# 2  peeking 2021-02-07 12:32:32   neutral     35
# 3    adore 2020-08-10 10:44:10  positive     72
# 4   scared 2021-06-08 06:56:52  negative     15
# 5  dislike 2020-07-22 10:41:19  negative     10
# 6  disgust 2021-03-30 17:47:26  negative      0
# 7     hate 2021-02-18 09:20:59  negative      5
# 8     want 2020-12-05 13:32:27  positive     70
# 9     love 2020-07-14 18:19:05  positive     65

# %%
Catogory_Score=mergedwithreaction.groupby("Category")["Score"].sum().reset_index(name="Score")

# %%
Top5Records=Catogory_Score.head(5)

# %%
Top5Catogories=Top5Records[["Category"]].head(5)

# %%
Top5Catogories
# Out:
#     Category
# 0    animals
# 1    cooking
# 2    culture
# 3  education
# 4       food

# %%
mergedwithreaction.to_csv('CleanedDataSet.csv', index=False)

# %%
Top5Catogories.to_csv("Top5Catogories.csv",index=False)

# %%
with pd.ExcelWriter('combined_data.xlsx') as writer:
    mergedwithreaction.to_excel(writer, sheet_name='Cleaned Data Set', index=False)
    Top5Catogories.to_excel(writer, sheet_name='Top5Catogories', index=False)

# %%
#Plotting the Values

# %%
mergedwithreaction.head(20)
# Out:
#                               Content ID  \
# 0   36d36f19-7a10-4d7d-a3ab-a3f2cbbfcf4a
# 1   f1038e6c-5292-4e20-a866-675e1637d6b5
# 2   ff883828-a610-492d-8635-8a777eaad25f
# 3   a3e93c2d-7fb4-4881-994d-ee20ad564924
# 4   b4c71928-99f0-4f1e-bdff-3d99c16113ac
# 5   4b10b6a2-d8ad-4f48-835a-e0ec47e7e72c
# 6   802a8533-3051-4e2c-ad30-7751ece5d514
# 7   9ee8836d-af4b-46ad-8869-4e0b1dedff7d
# 8   b81f446e-be9b-4fff-8faf-7732c6306c75
# 9   b07a2298-7c03-49b3-a0a6-c65333847598
# 10  fc346df4-d165-4ed0-8d43-a6896daf908e
# 11  88cbf75c-79f0-42cb-8733-af670f39d6e0
# 12  4c009116-c94a-4633-83fb-956565358565
# 13  3cec7ac2-f9b6-4e4c-b392-63c59c3621f2
# 14  6fd589e8-53ab-4345-896a-f428a92fcbe6
# 16  a38cf15e-6a1d-42e8-bee7-0eeb456c700b
# 17  6a39e0b5-b1cd-4edd-bdfb-310e1a3e5910
# 18  f8119ef8-1f00-49e4-b468-86dd64042053
# 19  1cd59d79-a2ca-4a99-92aa-2775117c4589
# 20  87958932-6baf-4339-b01b-6112d9b180ed
#
#                                  User ID Type_x         Category  \
# 0   69532ce2-1ffe-4187-8042-0230d115b24e  photo             food
# 1   13f0db8a-152a-496f-a6e8-1ed6a90b8788    GIF           soccer
# 2   ded166ee-173b-4a56-bc6d-464c35709670  photo        education
# 3   317c70d5-fe65-4663-afb1-150108e0e55c  video  public speaking
# 4   bf721d00-4fa1-44b1-834f-4730cd51aefa  video           travel
# 5   bf721d00-4fa1-44b1-834f-4730cd51aefa  photo        education
# 6   600118fa-e6f4-4d74-aeb6-936abbbf38a1  audio             food
# 7   90e2caab-9daa-4bf0-8104-c25e6c70c59d  audio           tennis
# 8   d1a89d23-7d17-4949-9e1a-637317141f3d  audio          cooking
# 9   ad4bd878-55e7-487c-a4db-470b23bbd832    GIF          culture
# 10  4bcb2c2e-36ed-4d5d-90a1-440993e9f6d2  video  public speaking
# 11  b473e898-b7b0-4a57-959d-484bf4cc4483  audio          animals
# 12  6fd58dea-315a-4ab2-8023-424a6ff455cd  photo           soccer
# 13  5b62e10e-3c19-4d28-a57c-e9bdc3d6758d    GIF   healthy eating
# 14  561b08d6-1084-4115-933d-db3e60edfd8b  video        education
# 16  30be2156-59d1-451e-beea-1a3690200a2b  video           travel
# 17  c64c5004-6ab5-4faa-9fcd-8039fe57799d    GIF           soccer
# 18  375985a6-ae79-43d2-b7c6-b182d83f1eaf  photo          culture
# 19  b870b764-7447-4990-a8d4-024d33e0e67d  audio          science
# 20  5ff89fb3-b364-494f-b62d-07097b2ffa12  audio          culture
#
#                                                   URL      Type_y  \
# 0   https://socialbuzz.cdn.com/content/storage/36d...     worried
# 1   https://socialbuzz.cdn.com/content/storage/f10...     cherish
# 2   https://socialbuzz.cdn.com/content/storage/ff8...     peeking
# 3   https://socialbuzz.cdn.com/content/storage/a3e...       adore
# 4   https://socialbuzz.cdn.com/content/storage/b4c...      scared
# 5   https://socialbuzz.cdn.com/content/storage/4b1...     dislike
# 6   https://socialbuzz.cdn.com/content/storage/802...     disgust
# 7   https://socialbuzz.cdn.com/content/storage/9ee...        hate
# 8   https://socialbuzz.cdn.com/content/storage/b81...        want
# 9   https://socialbuzz.cdn.com/content/storage/b07...        love
# 10  https://socialbuzz.cdn.com/content/storage/fc3...        love
# 11  https://socialbuzz.cdn.com/content/storage/88c...  super love
# 12  https://socialbuzz.cdn.com/content/storage/4c0...  interested
# 13  https://socialbuzz.cdn.com/content/storage/3ce...     peeking
# 14  https://socialbuzz.cdn.com/content/storage/6fd...        love
# 16  https://socialbuzz.cdn.com/content/storage/a38...        like
# 17  https://socialbuzz.cdn.com/content/storage/6a3...     peeking
# 18  https://socialbuzz.cdn.com/content/storage/f81...        want
# 19  https://socialbuzz.cdn.com/content/storage/1cd...      scared
# 20  https://socialbuzz.cdn.com/content/storage/879...      scared
#
#               Datetime Sentiment  Score
# 0  2021-02-12 00:36:14  negative     12
# 1  2020-09-01 12:38:42  positive     70
# 2  2021-02-07 12:32:32   neutral     35
# 3  2020-08-10 10:44:10  positive     72
# 4  2021-06-08 06:56:52  negative     15
# 5  2020-07-22 10:41:19  negative     10
# 6  2021-03-30 17:47:26  negative      0
# 7  2021-02-18 09:20:59  negative      5
# 8  2020-12-05 13:32:27  positive     70
# 9  2020-07-14 18:19:05  positive     65
# 10 2020-09-26 14:19:03  positive     65
# 11 2020-10-09 06:07:21  positive     75
# 12 2020-12-16 22:54:33  positive     30
# 13 2020-09-29 15:38:29   neutral     35
# 14 2021-04-17 11:05:23  positive     65
# 16 2020-10-27 12:38:55  positive     50
# 17 2020-11-23 08:41:19   neutral     35
# 18 2021-05-18 05:54:33  positive     70
# 19 2020-08-18 00:50:44  negative     15
# 20 2020-11-13 03:25:01  negative     15
